# %% [markdown]
# <a href="https://colab.research.google.com/github/Ab2207/Academic-Projects-Data-Analytics/blob/main/Fetching%20images%20from%20a%20video.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
import cv2 
import os 
  
# Read the video from specified path 
cam = cv2.VideoCapture("/content/gdrive/My Drive/Colab Notebooks/5.mp4") 
  
try: 
      
    # creating a folder named data 
    if not os.path.exists('data_from_colab'): 
        os.makedirs('data_from_colab') 
  
# if not created then raise error 
except OSError: 
    print ('Error: Creating directory of data') 
  
# frame 
currentframe = 0
  
while(True): 
      
    # reading from frame 
    ret,frame = cam.read() 
  
    if ret: 
        # if video is still left continue creating images 
        name = './data_from_colab/frame' + str(currentframe) + '.jpg'
        print ('Creating...' + name) 
  
        # writing the extracted images 
        cv2.imwrite(name, frame) 
  
        # increasing counter so that it will 
        # show how many frames are created 
        currentframe += 1
    else: 
        break
  
# Release all space and windows once done 
cam.release() 
cv2.destroyAllWindows()
# Out:
# Streaming output truncated to the last 5000 lines.
# Creating..../data_from_colab/frame15478.jpg
# Creating..../data_from_colab/frame15479.jpg
# Creating..../data_from_colab/frame15480.jpg
# Creating..../data_from_colab/frame15481.jpg
# Creating..../data_from_colab/frame15482.jpg
# Creating..../data_from_colab/frame15483.jpg
# Creating..../data_from_colab/frame15484.jpg
# Creating..../data_from_colab/frame15485.jpg
# Creating..../data_from_colab/frame15486.jpg
# Creating..../data_from_colab/frame15487.jpg
# Creating..../data_from_colab/frame15488.jpg
# Creating..../data_from_colab/frame15489.jpg
# Creating..../data_from_colab/frame15490.jpg
# Creating..../data_from_colab/frame15491.jpg
# Creating..../data_from_colab/frame15492.jpg
# Creating..../data_from_colab/frame15493.jpg
# Creating..../data_from_colab/frame15494.jpg
# Creating..../data_from_colab/frame15495.jpg
# Creating..../data_from_colab/frame15496.jpg
# Creating..../data_from_colab/frame15497.jpg
# ...
